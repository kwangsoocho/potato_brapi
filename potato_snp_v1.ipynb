# %%
import pandas as pd
df1 = pd.read_csv('germplasm_info_kor.csv')
df2 = pd.read_csv('germplasm_info_jap.csv')
df3 = pd.read_csv('germplasm_info_US.csv')
df4 = pd.read_csv('germplasm_info_landrace.csv')
df5 = pd.read_csv('110g_6575m.csv')
df6 = pd.read_csv('393g_3977m.csv')

# %% [markdown]
# # 110 Korean potato germplasm information

# %%
df1
# Out:
#      Unnamed: 0        Clone       Species   Mother     Father  \
# 0             1      Mangang  S. tuberosum  Atlantic  IT244159
# 1             2     Gangseon   S.tuberosum    DK1-83   Chubaek
# 2             3        Tamna  S. tuberosum      AJ09     Jeseo
# 3             4         Dano  S. tuberosum  Superior      KS13
# 4             5  Golden Ball  S. tuberosum   DK1-110   DK1-116
# ..          ...          ...           ...       ...       ...
# 105         106           R5  S. tuberosum         -         -
# 106         107           R6  S. tuberosum         -         -
# 107         108         1833  S. tuberosum         -         -
# 108         109         2048  S. tuberosum         -         -
# 109         110      B9482-3  S. tuberosum         -         -
#
#            Category Ploidy           Market Maturity Release year  \
# 0    Korean variety     4x  chip processing     late         2016
# 1    Korean variety     4x      table stock     late         2016
# ...

# %% [markdown]
# # 94 Japan potato germplasm information

# %%
df2
# Out:
#     Unnamed: 0           Clone      Species ploidy         Female  \
# 0            1          Norin1  S.tuberosum     4x  Irish Cobbler
# 1            2           Eniwa  S.tuberosum     4x   Shimakei 267
# 2            3        Yukijiro  S.tuberosum     4x       Kennebec
# 3            4         Chijiwa  S.tuberosum     4x      S54042-15
# 4            5      Hokkai-aka  S.tuberosum     4x    2070-ab(31)
# ..         ...             ...          ...    ...            ...
# 89          90      Konayutaka  S.tuberosum     4x     Kon-iku 38
# 90          91      Sanjyumaru  S.tuberosum     4x     Chokei 107
# 91          92           10H17  S.tuberosum     4x      Saikai 35
# 92          93        Harimaru  S.tuberosum     4x      Saikai 35
# 93          94  NagasakiKogane  S.tuberosum     4x      Saikai 35
#
#             Male   Release year                          Category  \
# 0        Deodara           1943                  Japanese variety
# ...

# %% [markdown]
# # 186 USA potato germplasm information

# %%
df3
# Out:
#      Unnamed: 0           Clone country                       Species  \
# 0             1       A97066-42      US  S. tuberosum Group Tuberosum
# 1             2  AdirondackBlue      US  S. tuberosum Group Tuberosum
# 2             3       AF2291-10      US  S. tuberosum Group Tuberosum
# 3             4        AF2376-5      US  S. tuberosum Group Tuberosum
# 4             5        AF2574-1      US  S. tuberosum Group Tuberosum
# ..          ...             ...     ...                           ...
# 181         182          Bintje      NL  S. tuberosum Group Tuberosum
# 182         183       Patagonia      CL  S. tuberosum Group Tuberosum
# 183         184  PurplePeruvian     NaN  S. tuberosum Group Tuberosum
# 184         185         AllBlue     NaN  S. tuberosum Group Tuberosum
# 185         186    IrishCobbler     NaN  S. tuberosum Group Tuberosum
#
#                     Market Ploidy            Release Year  \
# 0    French Fry Processing     4x  Advanced Breeding Line
# ...

# %% [markdown]
# # 14 landrace potato germplaminformation

# %%
df4
# Out:
#     Unnamed: 0            Clone       Species                         Market  \
# 0          1.0           Bintje  S. tuberosum                         Yellow
# 1          2.0        EarlyRose  S. tuberosum  red skinned Round White Table
# 2          3.0      GarnetChile  S. tuberosum                      Pigmented
# 3          4.0    GreenMountain  S. tuberosum              Round White Table
# 4          5.0       Hindenburg  S. tuberosum              Round White Table
# 5          6.0    RussetBurbank  S. tuberosum          French Fry Processing
# 6          7.0          Triumph  S. tuberosum                      Pigmented
# 7          8.0         MayQueen  S. tuberosum                    Table stock
# 8          9.0     IrishCobbler  S. tuberosum              Round White Table
# 9         10.0         All Blue  S. tuberosum                      Pigmented
# 10        11.0      Kintoki-imo  S. tuberosum                      Pigmented
# ...

# %% [markdown]
# # Potato 6575 SNP marker information of 110 korean germpalsm

# %%
df5
# Out:
#                    marker    chr    position    SNP   maf BakeKing  \
# 0     solcap_snp_c1_10354  chr01  84979169.0  [A/T]  0.21     AAAT
# 1     solcap_snp_c1_10358  chr01  84900698.0  [T/G]  0.20     AAAC
# 2     solcap_snp_c1_10915  chr01    481295.0  [T/C]  0.33     AGGG
# 3     solcap_snp_c1_10918  chr01    497066.0  [T/C]  0.38     AGGG
# 4     solcap_snp_c1_10924  chr01    551280.0  [A/G]  0.41     AGGG
# ...                   ...    ...         ...    ...   ...      ...
# 6572   solcap_snp_c2_7995  chr12  57611789.0  [T/C]  0.46      NaN
# 6573   solcap_snp_c2_8037  chr12  57705706.0  [T/C]  0.47     AAAG
# 6574   solcap_snp_c2_9486  chr12  27966948.0  [A/G]  0.47     AGGG
# 6575                  NaN    NaN         NaN    NaN   NaN      NaN
# 6576                  NaN    NaN         NaN    NaN   NaN      NaN
#
#      ArirangNo.1 Triumph Oryun RedMoon  ... Daekwan2-41 Chuyoung Eunseon  \
# 0           ATTT    ATTT  AAAT    AAAA  ...        AAAT     AAAT    AAAT
# ...

# %% [markdown]
# # Potato 3977 SNP marker information of 393 germplasm merged with Korea, Japan, US and landrace

# %%
df6
# Out:
#                    marker    chr  position    SNP   maf Norin1 Eniwa Yukijiro  \
# 0      solcap_snp_c1_3853  chr01  72112445  [T/G]  0.05   ABBB  BBBB     BBBB
# 1      solcap_snp_c1_3854  chr01  72112573  [A/G]  0.05   ABBB  BBBB     BBBB
# 2      solcap_snp_c1_4615  chr01  74352528  [T/C]  0.05   AAAA  AAAA     AAAA
# 3     solcap_snp_c2_49935  chr01   4603173  [A/G]  0.05   AAAA  AAAA     AAAA
# 4      solcap_snp_c1_6668  chr01   2753906  [T/C]  0.05   BBBB  BBBB     BBBB
# ...                   ...    ...       ...    ...   ...    ...   ...      ...
# 3972  solcap_snp_c2_23308  chr12  53190167  [A/G]  0.48   AABB  AAAB     AABB
# 3973  solcap_snp_c2_34807  chr12   8030835  [T/C]  0.49   ABBB  AABB     ABBB
# 3974  solcap_snp_c2_23284  chr12  53304636  [A/G]  0.49   AAAB  AAAB     AABB
# 3975  solcap_snp_c2_25372  chr12   1324476  [T/C]  0.50   AABB  AAAB     AABB
# 3976  solcap_snp_c1_14396  chr12  48732241  [T/C]  0.50   AABB  AABB     AABB
#
# ...
